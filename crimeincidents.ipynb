# %% [markdown]
# This dataset contains crime incident records with intentionally messy and inconsistent data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/crime_incidents_messy.csv")

# %%
df
# Out:
#      incident_id        crime_type     district         city state  \
# 0      INC001115             asslt          Sou    Maplewood    GA
# 1      INC004706          burglary    southeast    Maplewood    OH
# 2      INC002249          Homocide  Southwest       Lakewood    AZ
# 3      INC000021   Property Damage          Cen  Springfield    AZ
# 4      INC000488  Domestc Violence        North     Lakewood    PA
# ...          ...               ...          ...          ...   ...
# 5245   INC003247          Burglary          Nor  Springfield    OH
# 5246   INC000314          Vandlism    NORTHWEST    Maplewood    FL
# 5247   INC002761             Arson    northwest     Fairview    FL
# 5248   INC001022              Scam       East      Maplewood    TX
# 5249   INC003216         VANDALISM         west  Springfield    NY
#
#                   address    latitude   longitude    incident_datetime  \
# 0         2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   incident_id         5250 non-null   object
#  1   crime_type          5250 non-null   object
#  2   district            5250 non-null   object
#  3   city                5250 non-null   object
#  4   state               5250 non-null   object
#  5   address             5250 non-null   object
#  6   latitude            4992 non-null   float64
#  7   longitude           4961 non-null   float64
#  8   incident_datetime   4910 non-null   object
#  9   officer_id          5250 non-null   object
#  10  officer_first_name  5250 non-null   object
#  11  officer_last_name   5250 non-null   object
#  12  badge_number        4938 non-null   float64
#  13  suspect_id          4440 non-null   object
#  14  suspect_first_name  4440 non-null   object
# ...

# %%
df.describe()
# Out:
#           latitude    longitude  badge_number  suspect_age   victim_age  \
# count  4992.000000  4961.000000   4938.000000  4153.000000  4688.000000
# mean     40.778811   -88.607610   5558.581612    48.418493    52.349403
# std      23.243225    37.214207   2591.581049    43.504819    48.104315
# min      25.002420  -121.975849   1002.000000   -75.000000   -90.000000
# 25%      30.966472  -108.040512   3316.250000    29.000000    27.750000
# 50%      36.967123   -94.656440   5567.000000    46.000000    49.000000
# 75%      43.051502   -80.588056   7862.000000    62.000000    71.000000
# max     199.984200    99.787300   9999.000000   298.000000   298.000000
#
#        num_arrests
# count  4917.000000
# mean      2.262152
# std       1.994556
# min      -5.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
df.head()
# Out:
#   incident_id        crime_type     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address    latitude   longitude    incident_datetime  \
# 0      2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# 1         2361 Park Rd   29.422717  -77.167016  2022-01-11 22:03:29
# 2         1067 Main St   39.411460  -98.615298  2022-04-14 11:39:24
# 3  4713 Washington Ave   28.633439  -99.030051  2020-12-09 15:14:24
# 4        1371 River Rd   34.217850 -121.614731  2021-07-24 20:08:13
#
#   officer_id  ... victim_gender  victim_phone  weapon_used severity  \
# 0    OFF0078  ...       Unknown    6223265920      Firearm        2
# ...

# %%
df.isna().sum()
# Out:
# incident_id              0
# crime_type               0
# district                 0
# city                     0
# state                    0
# address                  0
# latitude               258
# longitude              289
# incident_datetime      340
# officer_id               0
# officer_first_name       0
# officer_last_name        0
# badge_number           312
# suspect_id             810
# suspect_first_name     810
# suspect_last_name      810
# suspect_age           1097
# suspect_gender        1413
# suspect_race          1601
# victim_id              257
# victim_first_name      257
# victim_last_name       257
# victim_age             562
# victim_gender         1000
# victim_phone          1056
# weapon_used            970
# severity               355
# case_status            731
# resolution             951
# num_arrests            333
# property_loss_usd      436
# reported_online        504
# notes                 1069
# dtype: int64

# %%
df.isnull().sum()
# Out:
# incident_id              0
# crime_type               0
# district                 0
# city                     0
# state                    0
# address                  0
# latitude               258
# longitude              289
# incident_datetime      340
# officer_id               0
# officer_first_name       0
# officer_last_name        0
# badge_number           312
# suspect_id             810
# suspect_first_name     810
# suspect_last_name      810
# suspect_age           1097
# suspect_gender        1413
# suspect_race          1601
# victim_id              257
# victim_first_name      257
# victim_last_name       257
# victim_age             562
# victim_gender         1000
# victim_phone          1056
# weapon_used            970
# severity               355
# case_status            731
# resolution             951
# num_arrests            333
# property_loss_usd      436
# reported_online        504
# notes                 1069
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# suspect_race          1601
# suspect_gender        1413
# suspect_age           1097
# notes                 1069
# victim_phone          1056
# victim_gender         1000
# weapon_used            970
# resolution             951
# suspect_last_name      810
# suspect_id             810
# suspect_first_name     810
# case_status            731
# victim_age             562
# reported_online        504
# property_loss_usd      436
# severity               355
# incident_datetime      340
# num_arrests            333
# badge_number           312
# longitude              289
# latitude               258
# victim_id              257
# victim_last_name       257
# victim_first_name      257
# incident_id              0
# officer_first_name       0
# officer_id               0
# officer_last_name        0
# crime_type               0
# state                    0
# city                     0
# district                 0
# address                  0
# dtype: int64

# %%
corr=df.corr(numeric_only=True)

# %%
corr
# Out:
#               latitude  longitude  badge_number  suspect_age  victim_age  \
# latitude      1.000000   0.003188      0.013639     0.004008   -0.001386
# longitude     0.003188   1.000000     -0.001085     0.022343   -0.004557
# badge_number  0.013639  -0.001085      1.000000    -0.014812   -0.014733
# suspect_age   0.004008   0.022343     -0.014812     1.000000   -0.008427
# victim_age   -0.001386  -0.004557     -0.014733    -0.008427    1.000000
# num_arrests   0.006767  -0.024555     -0.002319    -0.004556    0.019536
#
#               num_arrests
# latitude         0.006767
# longitude       -0.024555
# badge_number    -0.002319
# suspect_age     -0.004556
# victim_age       0.019536
# num_arrests      1.000000

# %%
plt.figure(figsize=(7,7))
df["suspect_gender"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title('Distribution of Suspect Gender')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y="badge_number", data=df)
plt.title("Distribution of badge_number")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df["victim_age"])
plt.title("Boxplot of Victim Age")
plt.ylabel("Victim Age")
plt.show()

# %%
df["incident_datetime"] = pd.to_datetime(
    df["incident_datetime"],
    errors="coerce"
)

# %%
df["incident_datetime"]
# Out:
# 0      2024-04-16 08:45:03
# 1      2022-01-11 22:03:29
# 2      2022-04-14 11:39:24
# 3      2020-12-09 15:14:24
# 4      2021-07-24 20:08:13
#                ...
# 5245   2021-12-18 17:27:18
# 5246   2023-06-23 04:09:19
# 5247   2018-04-25 14:38:24
# 5248   2023-03-29 09:54:50
# 5249                   NaT
# Name: incident_datetime, Length: 5250, dtype: datetime64[ns]

# %%
plt.figure(figsize=(9,6))
sns.histplot(df["victim_age"],kde=True)
plt.title("Distribution of Victim Age")
plt.show()

# %%
df["victim_age"].value_counts()
# Out:
# victim_age
#  21.0     73
#  67.0     70
#  12.0     70
#  15.0     69
#  84.0     68
#           ..
#  210.0     1
#  183.0     1
#  234.0     1
# -39.0      1
#  150.0     1
# Name: count, Length: 260, dtype: int64

# %%
df["victim_age"] = pd.to_numeric(
    df["victim_age"], errors="coerce"
)

# %%
df["victim_age"]
# Out:
# 0        51.0
# 1       231.0
# 2        29.0
# 3       243.0
# 4        51.0
#         ...
# 5245     84.0
# 5246    -75.0
# 5247     77.0
# 5248     72.0
# 5249      NaN
# Name: victim_age, Length: 5250, dtype: float64

# %%
df.loc[
    (df["victim_age"] < 0) | (df["victim_age"] > 120),
    "victim_age"
] = np.nan

# %%
df["victim_age"].value_counts(dropna=False)
# Out:
# victim_age
# NaN     970
# 21.0     73
# 67.0     70
# 12.0     70
# 15.0     69
#        ...
# 20.0     42
# 18.0     41
# 81.0     39
# 16.0     39
# 56.0     35
# Name: count, Length: 82, dtype: int64

# %%
df["crime_type"].value_counts()
# Out:
# crime_type
# Fire Setting         84
# DV                   82
# ARSON                80
# Drug Offence         79
# Deception            79
#                      ..
#   Sex Assault         1
# assault & battery     1
# CYBER  CRIME          1
#   dui                 1
#   theft/larceny       1
# Name: count, Length: 182, dtype: int64

# %%
plt.figure(figsize=(10,5))
df["crime_type"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Crime Types")
plt.xlabel("Crime Type")
plt.ylabel("Number of Incidents")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(200)

# %%
df["incident_id"].duplicated().sum()
# Out:
# np.int64(200)

# %%
df = df.drop_duplicates()

df = df.drop_duplicates(
    subset="incident_id",
    keep="first"
)

# %%
df
# Out:
#      incident_id        crime_type     district         city state  \
# 0      INC001115             asslt          Sou    Maplewood    GA
# 1      INC004706          burglary    southeast    Maplewood    OH
# 2      INC002249          Homocide  Southwest       Lakewood    AZ
# 3      INC000021   Property Damage          Cen  Springfield    AZ
# 4      INC000488  Domestc Violence        North     Lakewood    PA
# ...          ...               ...          ...          ...   ...
# 5245   INC003247          Burglary          Nor  Springfield    OH
# 5246   INC000314          Vandlism    NORTHWEST    Maplewood    FL
# 5247   INC002761             Arson    northwest     Fairview    FL
# 5248   INC001022              Scam       East      Maplewood    TX
# 5249   INC003216         VANDALISM         west  Springfield    NY
#
#                   address    latitude   longitude   incident_datetime  \
# 0         2830 Cedar Lane  170.284100  -77.500710 2024-04-16 08:45:03
# ...

# %%
df["num_arrests"] = pd.to_numeric(
    df["num_arrests"], errors="coerce"
)

df["property_loss_usd"] = pd.to_numeric(
    df["property_loss_usd"], errors="coerce"
)

df.loc[df["num_arrests"] < 0, "num_arrests"] = np.nan

df.loc[df["property_loss_usd"] < 0, "property_loss_usd"] = np.nan

# %%
(df.isna().mean()*100)
# Out:
# incident_id            0.000000
# crime_type             0.000000
# district               0.000000
# city                   0.000000
# state                  0.000000
# address                0.000000
# latitude               4.970297
# longitude              5.504950
# incident_datetime     13.722772
# officer_id             0.000000
# officer_first_name     0.000000
# officer_last_name      0.000000
# badge_number           5.960396
# suspect_id            15.346535
# suspect_first_name    15.346535
# suspect_last_name     15.346535
# suspect_age           20.831683
# suspect_gender        26.772277
# suspect_race          30.198020
# victim_id              4.910891
# victim_first_name      4.910891
# victim_last_name       4.910891
# victim_age            18.435644
# victim_gender         19.069307
# victim_phone          20.178218
# weapon_used           18.415842
# severity               6.772277
# case_status           13.782178
# resolution            18.059406
# ...

# %%
df.describe(include="object")
# Out:
#        incident_id crime_type district       city state        address  \
# count         5050       5050     5050       5050  5050           5050
# unique        5050        182      131          8    10           4895
# top      INC003216         DV      Nor  Riverside    FL  8687 Maple Dr
# freq             1         81      262        705   536              3
#
#        officer_id officer_first_name officer_last_name suspect_id  ...  \
# count        5050               5050              5050       4275  ...
# unique        150                128                30        798  ...
# top       OFF0069            Jessica          Anderson   SUS00130  ...
# freq           52                189               191         14  ...
#
#        victim_first_name victim_last_name victim_gender  victim_phone  \
# count               4802             4802          4087          4031
# unique                30               30            12          3994
# ...

# %%
df[["victim_gender","victim_phone"]].drop_duplicates()
# Out:
#      victim_gender  victim_phone
# 0          Unknown    6223265920
# 1              NaN  241-973-4826
# 2            Other  244-584-7696
# 3              NaN    5021227484
# 4                M    9698766873
# ...            ...           ...
# 5243        female  414-257-4028
# 5244        FEMALE  953-979-4479
# 5245             m  534-870-3834
# 5247         Other  796-911-1169
# 5248        female  214-897-2917
#
# [4007 rows x 2 columns]

# %%
missing_values=df.isnull().sum()
missing_values[missing_values>0].sort_values(ascending=False)
# Out:
# suspect_race          1525
# suspect_gender        1352
# suspect_age           1052
# notes                 1028
# victim_phone          1019
# victim_gender          963
# victim_age             931
# weapon_used            930
# resolution             912
# suspect_first_name     775
# suspect_last_name      775
# suspect_id             775
# property_loss_usd      745
# case_status            696
# incident_datetime      693
# num_arrests            499
# reported_online        486
# severity               342
# badge_number           301
# longitude              278
# latitude               251
# victim_last_name       248
# victim_id              248
# victim_first_name      248
# dtype: int64

# %%
df["property_loss_usd"]
# Out:
# 0            NaN
# 1       44839.49
# 2       15963.38
# 3       48680.14
# 4       23513.01
#           ...
# 5245    44417.98
# 5246    16330.48
# 5247    13138.25
# 5248    43851.12
# 5249    38856.84
# Name: property_loss_usd, Length: 5050, dtype: float64

# %%
df["suspect_race"].isna().sum()
# Out:
# np.int64(1525)

# %%
df["suspect_race"].value_counts()
# Out:
# suspect_race
# Black       381
# BLACK       370
# Hispanic    367
# Unknown     363
# asian       353
# hispanic    352
# White       349
# white       333
# Other       329
# Asian       328
# Name: count, dtype: int64

# %%
df["suspect_age"] = pd.to_numeric(
    df["suspect_age"], errors="coerce"
)

# %%
df["suspect_age"]
# Out:
# 0        51.0
# 1       -28.0
# 2        19.0
# 3       262.0
# 4        75.0
#         ...
# 5245     60.0
# 5246     36.0
# 5247      NaN
# 5248     35.0
# 5249      NaN
# Name: suspect_age, Length: 5050, dtype: float64

# %%
df["suspect_race"]=df["suspect_race"].str.strip()
df["suspect_race"]=df["suspect_race"].str.lower()
df["suspect_race"]=df["suspect_race"].str.title()

# %%
df["suspect_race"]
# Out:
# 0          Asian
# 1          Black
# 2          Asian
# 3          Black
# 4          White
#           ...
# 5245       White
# 5246    Hispanic
# 5247         NaN
# 5248         NaN
# 5249         NaN
# Name: suspect_race, Length: 5050, dtype: object

# %%
df.loc[
    (df["suspect_age"] < 0) | (df["suspect_age"] > 120),
    "suspect_age"
] = np.nan

# %%
df["suspect_age"].value_counts(dropna=False)
# Out:
# suspect_age
# NaN     1375
# 36.0      82
# 19.0      78
# 46.0      73
# 26.0      72
#         ...
# 17.0      48
# 60.0      48
# 23.0      47
# 39.0      44
# 21.0      34
# Name: count, Length: 62, dtype: int64

# %%
gender_map = {
    "M": "Male",
    "m": "Male",
    "MALE": "Male",
    "male": "Male",
    "F": "Female",
    "f": "Female",
    "FEMALE": "Female",
    "female": "Female"
}

df["suspect_gender"] = df["suspect_gender"].replace(gender_map)
df["victim_gender"] = df["victim_gender"].replace(gender_map)

# %%
df["suspect_gender"].value_counts(dropna=False)
# Out:
# suspect_gender
# Female     1578
# Male       1509
# NaN        1352
# Other       306
# Unknown     305
# Name: count, dtype: int64

# %%
df["victim_age"].value_counts(dropna=False)
# Out:
# victim_age
# NaN     931
# 21.0     70
# 12.0     69
# 67.0     68
# 84.0     64
#        ...
# 18.0     41
# 25.0     41
# 16.0     39
# 81.0     38
# 56.0     34
# Name: count, Length: 82, dtype: int64

# %%
num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

cat_cols = df.select_dtypes(include="object").columns

for col in cat_cols:
    df[col] = df[col].fillna("Unknown")

# %%
df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
df.loc[
    (df["latitude"] < -90) | (df["latitude"] > 90),
    "latitude"
] = np.nan

# %%
df["latitude"]
# Out:
# 0             NaN
# 1       29.422717
# 2       39.411460
# 3       28.633439
# 4       34.217850
#           ...
# 5245    42.576022
# 5246    38.941858
# 5247    41.627732
# 5248    28.903176
# 5249    30.859979
# Name: latitude, Length: 5050, dtype: float64

# %%
df["longitude"]= pd.to_numeric(df["longitude"], errors="coerce")
df.loc[
    (df["longitude"] < -180) | (df["longitude"] > 180),
    "longitude"
] = np.nan

# %%
df["longitude"]
# Out:
# 0       -77.500710
# 1       -77.167016
# 2       -98.615298
# 3       -99.030051
# 4      -121.614731
#            ...
# 5245    -79.788519
# 5246   -108.480924
# 5247    -82.048681
# 5248   -111.840384
# 5249    -78.590392
# Name: longitude, Length: 5050, dtype: float64

# %%
plt.figure(figsize=(10,6))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(869)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   incident_id        crime_type     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address   latitude   longitude   incident_datetime officer_id  \
# 0      2830 Cedar Lane        NaN  -77.500710 2024-04-16 08:45:03    OFF0078
# 1         2361 Park Rd  29.422717  -77.167016 2022-01-11 22:03:29    OFF0059
# 2         1067 Main St  39.411460  -98.615298 2022-04-14 11:39:24    OFF0088
# 3  4713 Washington Ave  28.633439  -99.030051 2020-12-09 15:14:24    OFF0077
# 4        1371 River Rd  34.217850 -121.614731 2021-07-24 20:08:13    OFF0083
#
#    ... victim_gender  victim_phone  weapon_used severity case_status  \
# ...
